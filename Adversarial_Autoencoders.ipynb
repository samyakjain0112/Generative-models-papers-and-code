# %% [markdown]
# <a href="https://colab.research.google.com/github/samyakjain0112/Generative-models-papers-and-code/blob/master/Adversarial_Autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing all requirements
import torch as torch
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import torch.nn as nn
from torch.nn.functional import relu as Relu
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
from torchvision.utils import save_image
from sklearn.decomposition import PCA
import torch.nn.functional as F

# %%
#using the inbuilt Dataset class where all data is loaded into the cpu memory and using getitem we can get the data by just passing the corresponding index
train_data = dsets.MNIST(root = './data', train = True,
                        transform = transforms.ToTensor(), download = True)

test_data = dsets.MNIST(root = './data', train = False,
                       transform = transforms.ToTensor())

# %%
#loading all the data using Dataloaader inbuilt class it loads all the data again into the cpu memory without making a copy because it uses iter for it and even if suffle examples is true then also no cpy is 
#required it just reshuffles the order of the iteraror in the list. 
#NOTE: only when we will load the data for training in the training class then the data will be needed to be loaded in the gpu memory
batch_size=100
train_gen = torch.utils.data.DataLoader(dataset = train_data,
                                             batch_size = batch_size,
                                             shuffle = True)

test_gen = torch.utils.data.DataLoader(dataset = test_data,
                                      batch_size = batch_size, 
                                      shuffle = False)

# %%
#Usually in the model class we need to inherit from nn.Module and use super class code otherwise the forward will not run.


class model_encoder(torch.nn.Module):
  def __init__(self,batch_size=100):
    super(model_encoder,self).__init__()
    self.batch_size=batch_size
    self.latent_space_dim=10
    self.layer1=torch.nn.Linear(784,1000)
    self.layer2=torch.nn.Linear(1000,1000)
    #self.layer3=torch.nn.Maxpool2d((3,3),2)
    self.layer4=torch.nn.Linear(1000,self.latent_space_dim)
    
  def forward(self,x,latent_space=False,latent=None,marker=False,plot=False):
    x=F.relu(self.layer1(x))

    x=F.relu(self.layer2(x))
    #x=self.layer3(x)
    x=F.dropout(x,0.3)
    x=F.relu(self.layer4(x))
    if plot==True:
      return x
    if latent_space==True:
      return x
    return x

# %%
#Usually in the model class we need to inherit from nn.Module and use super class code otherwise the forward will not run.


class model_decoder(torch.nn.Module):
  def __init__(self,batch_size=100):
    super(model_decoder,self).__init__()
    self.batch_size=batch_size
    self.latent_space_dim=10
    self.layer5=torch.nn.Linear(self.latent_space_dim,1000)
    self.layer6=torch.nn.Linear(1000,1000)
    self.layer7=torch.nn.Linear(1000,784)

  def forward(self,x,latent_space=False,latent=None,marker=False,plot=False):
    if marker==True:
      x=latent
    x=F.relu(self.layer5(x))
    x=F.dropout(x,0.3)
    x=F.relu(self.layer6(x))
    x=F.sigmoid(self.layer7(x))

    return x

# %%
#Usually in the model class we need to inherit from nn.Module and use super class code otherwise the forward will not run.

#VARIABLE: SELF.NUM_LAYERS

class model_discriminator(torch.nn.Module):
  def __init__(self,batch_size=100):
    super(model_discriminator,self).__init__()
    self.batch_size=batch_size
    self.num_layers=1
    self.filter_size=28
    self.d_input_dim=10
    self.layer1_features=1000
    self.fc1 = nn.Linear(self.d_input_dim,self.layer1_features )
    self.fc2 = nn.Linear(self.fc1.out_features, self.fc1.out_features)
    self.fc3 = nn.Linear(self.fc2.out_features,1)

  def forward(self,x,latent_space=False,latent=None,marker=False,plot=False):
      x = F.leaky_relu(self.fc1(x), 0.2)
      x = F.dropout(x, 0.3)
      x = F.leaky_relu(self.fc2(x), 0.2)
      if plot==True:
        return x
      if latent_space==True:
        return x
      if marker==True:
        x=latent
      #x = F.dropout(x, 0.3)
      return torch.sigmoid(self.fc3(x))
      #x = F.leaky_relu(self.fc3(x), 0.2)
      #x = F.dropout(x, 0.3)
      #return torch.sigmoid(self.fc4(x))
"""
    if plot==True:
      return x
    if latent_space==True:
      return x
    if marker==True:
      x=latent
    x=self.layer3(x)
    x=Relu(x)
    x=torch.flatten(x,1)
    x=self.layer4(x)
    x=Relu(x)
    x=self.layer5(x)
    x=torch.sigmoid(x)
    #print(x.size())
    #x=x.cpu().detach().numpy()
    #x=np.array(np.amax(x,axis=1))
    
    
    #print(x.size())

    return x
"""
# Out:
# '\n    if plot==True:\n      return x\n    if latent_space==True:\n      return x\n    if marker==True:\n      x=latent\n    x=self.layer3(x)\n    x=Relu(x)\n    x=torch.flatten(x,1)\n    x=self.layer4(x)\n    x=Relu(x)\n    x=self.layer5(x)\n    x=torch.sigmoid(x)\n    #print(x.size())\n    #x=x.cpu().detach().numpy()\n    #x=np.array(np.amax(x,axis=1))\n    \n    \n    #print(x.size())\n\n    return x\n'

# %%
#latent space visualization
class modify_space(object):
  def __init__(self,importer,test_gen,label=1,label2=2,num_latents=10):
    self.batch_size=1
    self.label=label
    self.num_layers=1
    self.filter_size=28
    self.label2=label2
    self.test_gen=test_gen
    self.num_latents=num_latents
    self.net_encoder=importer.net_encoder
    self.net_decoder=importer.net_decoder
    self.net_discriminator=importer.net_discriminator
    self.generate()
    self.latent()


  def generate(self):
    w=0
    e=0
    print(1)
    for (image,label) in self.test_gen:
      if w==1:
        break
      for i in range(len(label)):
        if (label[i].item())==self.label:
          self.image=np.reshape(image[i],[self.batch_size, self.num_layers*self.filter_size*self.filter_size]).cuda()

          self.label=label[i].cuda()
          w=1
          break
    for (image,label) in self.test_gen:
      if e==1:
        break
      for i in range(len(label)):
        if (label[i].item())==self.label2:
          self.image2=np.reshape(image[i],[self.batch_size, self.num_layers*self.filter_size*self.filter_size]).cuda()
          self.label2=label[i].cuda()
          e=1
          break

  def latent(self):
    latent1=self.net_encoder(self.image,latent_space=True)
    latent2=self.net_encoder(self.image2,latent_space=True)
    for count in range(self.num_latents+1):
      input_latent=(latent1*(count/(self.num_latents))+latent2*(1-count/self.num_latents))
      output=self.net_decoder(self.image2,latent=input_latent,marker=True)
      output=output.view(1, 1,self.filter_size ,self.filter_size ) 
      save_image(output,'latent_layer1_'+str(count)+'.png')

# %%
#visualizing the latent space points in two dimenions using principal component analysis
a=0
class plotter(object):
  def __init__(self,render):
    self.batch_size=1
    self.test_gen=test_gen
    self.net_encoder=render.net_encoder
    self.net_discriminator=render.net_discriminator
    self.num_layers=1
    self.filter_size=28
    self.latent=[]
    self.latent_size=10
    self.label_array=[]
    self.visualize()
   
  def visualize(self):
    for (image,label) in self.test_gen:
      for i in range(len(label)):
        latent=self.net_encoder(np.reshape(image[i],[self.batch_size,self.num_layers*self.filter_size*self.filter_size]).cuda(),plot=True).cpu().detach().numpy()
        latent_x=np.reshape(latent,(self.latent_size))
        self.latent.append(latent_x)
        self.label_array.append(label[i].item())
        #feat_cols = ['feature'+str(i) for i in range(latent_x.shape[1])]
        #latent=pd.DataFrame(latent_x,columns=feat_cols)
        #print(latent.shape)
        #print(latent)

    pca_latent = PCA(n_components=2)
  
    twodim_pca = pca_latent.fit_transform(np.array(self.latent))
    colormap = np.array(['r', 'g', 'b','pink','orange','lightblue','black','brown','yellow','white'])
    for i in range(10):
      temp1=[]
      temp2=[]
      
      for j in range(len(self.label_array)):

        if self.label_array[j]==i:
          temp1.append(twodim_pca[j][0])
          temp2.append(twodim_pca[j][1]) 
      plt.scatter(temp1,temp2,c=colormap[i])
    plt.show()

# %%
#MAIN DO NOT TOUCH IT
net_encoder=model_encoder().cuda()
net_decoder=model_decoder().cuda()
net_discriminator=model_discriminator().cuda()

gen_lr = 0.0001
reg_lr = 0.00005
opt_encoder=torch.optim.Adam(net_encoder.parameters(),gen_lr)
opt_encoder_gen=torch.optim.Adam(net_encoder.parameters(),reg_lr)
opt_decoder=torch.optim.Adam(net_decoder.parameters(),gen_lr)
opt_discriminator=torch.optim.Adam(net_discriminator.parameters(),reg_lr)

# %%
#If we are building a class without using any functionality of any other class then object can be written it means that the class will return an object type dataset
#However if we write like data.Datasets of Sampler then it means that it will have functionality of the superclass data.Datasets or Sampler however ultimately these super classes will also return an object.
#so here in a way we are returning an object of the super class via the sub class.
#BUILDING A SIMPLE AUTOENCODER WHICH JUST AIMS AT RECONSTRUCTION WITHOUT ANY STOCHASTICITY


class training(object):

  def __init__(self,epochs=40,train_g=train_gen,test_g=test_gen,generate_latent=False,plot=False):
    self.epochs=epochs
   
    self.EPS = 1e-15
    self.train_gen=train_g
    self.batch_size=100
    self.test_gen=test_g
    self.device='cuda'
    self.mean=0
    self.variance=1
    self.num_layers=1
    self.filter_size=28
    self.net_encoder=net_encoder
    self.net_decoder= net_decoder
    self.net_discriminator=net_discriminator
    self.loss_regularization=torch.nn.BCELoss()
    self.loss_reconstruction=torch.nn.MSELoss
    self.opt_discriminator=opt_discriminator
    self.opt_encoder=opt_encoder
    self.opt_decoder=opt_decoder
    self.opt_encoder_gen=opt_encoder_gen
    self.generation_iters=1
    self.d_iters=1
    self.latent_space_dim=10
    self.train()
    if generate_latent==True:
      modify_space(self,test_gen)
    if plot==True:
      plotter(self)
    self.test()


  def train(self):
    for epoch_no in range(self.epochs):
      counter=0
      count=0
      for (image,label) in self.train_gen:
        count+=1
        img=image.to(self.device)
        input_noise=torch.from_numpy(np.random.normal(self.mean,self.variance,(self.batch_size,self.latent_space_dim))).to(self.device)
        lab_real=torch.from_numpy(np.ones([self.batch_size,1],np.float32)).to(self.device)
        lab_fake=torch.from_numpy(np.zeros([self.batch_size,1],np.float32)).to(self.device)

        #reconstruction loss
        self.opt_encoder.zero_grad()
        self.opt_encoder_gen.zero_grad()
        self.opt_encoder.zero_grad()
        self.opt_discriminator.zero_grad()
        img=img.view(self.batch_size,self.num_layers*self.filter_size*self.filter_size)
        encoder_outputs=self.net_encoder(img).to(self.device)
        decoder_outputs=self.net_decoder(encoder_outputs)
        #print(decoder_outputs.size())
        loss_reconstruction=torch.mean(torch.pow(decoder_outputs-img,2))
        loss_reconstruction.backward()
        opt_decoder.step()
        opt_encoder.step()

        #Regualization loss

        #discriminator training
        #noise_generation
        input_noise=torch.from_numpy(np.random.normal(self.mean,self.variance,(self.batch_size,self.latent_space_dim))).float().to(self.device)
        self.opt_discriminator.zero_grad()
        self.opt_encoder_gen.zero_grad()
        self.opt_encoder.zero_grad()
        loss_d=0
        if count%self.d_iters==0:
          
          encoder_outputs=self.net_encoder(img).to(self.device)
          logits_fake = self.net_discriminator(encoder_outputs).to(self.device)
          logits_real = self.net_discriminator(input_noise).to(self.device)
          loss_discriminator=-torch.mean(torch.log(logits_real + self.EPS) + torch.log(1 - logits_fake + self.EPS))
          #loss_discriminator_real = self.loss(logits_real,lab_real)
          #loss_discriminator_fake = self.loss(logits_fake,lab_fake)
          #loss_discriminator=loss_discriminator_real+loss_discriminator_fake
          loss_discriminator.backward()
          self.opt_discriminator.step()
          loss_d+=loss_discriminator
        #discriminator one iteration complete

        #train_generator
        tot_loss=0
        if count%self.generation_iters==0:
          
          self.opt_encoder_gen.zero_grad()
          self.opt_encoder.zero_grad()
          self.opt_discriminator.zero_grad()
          #self.opt_discriminator.zero_grad()
          
          #print("fake_image",output_generator.size())
          
          #loss_generator = self.loss(logit_disc,lab_real)
          encoder_outputs=self.net_encoder(img).to(self.device)
          logits_fake = self.net_discriminator(encoder_outputs).to(self.device)
          loss_generator=-torch.mean(torch.log(logits_fake + self.EPS))
          tot_loss+=loss_generator
          loss_generator.backward()
          self.opt_encoder_gen.step()
        #One generator iteration completed
        counter+=1
        print("ITERATION_NO.:",counter ,"LOSS_RECONSTRUCTION:",loss_discriminator.item(),"LOSS_Generator:",tot_loss.item()/self.generation_iters ,"LOSS_Discriminator:",loss_d.item()/self.d_iters)
      print("EPOCH OVER:",epoch_no)
   
  def test(self):
    count=0
    for (image,label) in self.train_gen:
      img=image[0].to(self.device)
      lab=label.to(self.device)
      input_noise=torch.from_numpy(np.random.normal(self.mean,self.variance,(self.batch_size,self.latent_space_dim))).float().to(self.device)
      outputs = self.net_decoder(input_noise).view(100,1,28,28)
      count+=1
      print("Image_no",count)
      if count%100==0:
        save_image(outputs,'testing'+str(count)+'.png')

# %%
#here is all it begins and ends
obj=training(plot=True,generate_latent=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Streaming output truncated to the last 5000 lines.
# ITERATION_NO.: 412 LOSS_RECONSTRUCTION: 0.021228820085525513 LOSS_Generator: 5.679339408874512 LOSS_Discriminator: 0.021228820085525513
# ITERATION_NO.: 413 LOSS_RECONSTRUCTION: 0.013217935338616371 LOSS_Generator: 5.693536281585693 LOSS_Discriminator: 0.013217935338616371
# ITERATION_NO.: 414 LOSS_RECONSTRUCTION: 0.04170174151659012 LOSS_Generator: 5.629064083099365 LOSS_Discriminator: 0.04170174151659012
# ITERATION_NO.: 44 LOSS_RECONSTRUCTION: 0.002714397618547082 LOSS_Generator: 6.316811561584473 LOSS_Discriminator: 0.002714397618547082
# ITERATION_NO.: 45 LOSS_RECONSTRUCTION: 0.05587173253297806 LOSS_Generator: 6.273394584655762 LOSS_Discriminator: 0.05587173253297806
# ITERATION_NO.: 46 LOSS_RECONSTRUCTION: 0.004089854657649994 LOSS_Generator: 6.048554420471191 LOSS_Discriminator: 0.004089854657649994
# ITERATION_NO.: 47 LOSS_RECONSTRUCTION: 0.008399584330618382 LOSS_Generator: 6.225126266479492 LOSS_Discriminator: 0.008399584330618382
# ITERATION_NO.: 48 LOSS_RECONSTRUCTION: 0.169393390417099 LOSS_Generator: 6.065920352935791 LOSS_Discriminator: 0.169393390417099
# ITERATION_NO.: 49 LOSS_RECONSTRUCTION: 0.005449536722153425 LOSS_Generator: 6.062015056610107 LOSS_Discriminator: 0.005449536722153425
# ITERATION_NO.: 50 LOSS_RECONSTRUCTION: 0.004434267058968544 LOSS_Generator: 6.091518878936768 LOSS_Discriminator: 0.004434267058968544
# ITERATION_NO.: 51 LOSS_RECONSTRUCTION: 0.004127901513129473 LOSS_Generator: 6.092065811157227 LOSS_Discriminator: 0.004127901513129473
# ITERATION_NO.: 52 LOSS_RECONSTRUCTION: 0.07167795300483704 LOSS_Generator: 6.118571758270264 LOSS_Discriminator: 0.07167795300483704
# ITERATION_NO.: 53 LOSS_RECONSTRUCTION: 0.022170085459947586 LOSS_Generator: 6.108699798583984 LOSS_Discriminator: 0.022170085459947586
# ITERATION_NO.: 54 LOSS_RECONSTRUCTION: 0.008857843466103077 LOSS_Generator: 6.100165843963623 LOSS_Discriminator: 0.008857843466103077
# ITERATION_NO.: 55 LOSS_RECONSTRUCTION: 0.007855584844946861 LOSS_Generator: 6.096664905548096 LOSS_Discriminator: 0.007855584844946861
# ITERATION_NO.: 56 LOSS_RECONSTRUCTION: 0.051025740802288055 LOSS_Generator: 5.94352388381958 LOSS_Discriminator: 0.051025740802288055
# ITERATION_NO.: 57 LOSS_RECONSTRUCTION: 0.004570709075778723 LOSS_Generator: 5.861256122589111 LOSS_Discriminator: 0.004570709075778723
# ITERATION_NO.: 58 LOSS_RECONSTRUCTION: 0.005912876222282648 LOSS_Generator: 5.823418617248535 LOSS_Discriminator: 0.005912876222282648
# ITERATION_NO.: 59 LOSS_RECONSTRUCTION: 0.04594104364514351 LOSS_Generator: 5.704478740692139 LOSS_Discriminator: 0.04594104364514351
# ITERATION_NO.: 60 LOSS_RECONSTRUCTION: 0.004803390242159367 LOSS_Generator: 5.676995754241943 LOSS_Discriminator: 0.004803390242159367
# ITERATION_NO.: 61 LOSS_RECONSTRUCTION: 0.00555127440020442 LOSS_Generator: 5.692407131195068 LOSS_Discriminator: 0.00555127440020442
# ITERATION_NO.: 62 LOSS_RECONSTRUCTION: 0.005555406212806702 LOSS_Generator: 5.684902667999268 LOSS_Discriminator: 0.005555406212806702
# ITERATION_NO.: 63 LOSS_RECONSTRUCTION: 0.04269441217184067 LOSS_Generator: 5.771066665649414 LOSS_Discriminator: 0.04269441217184067
# ITERATION_NO.: 64 LOSS_RECONSTRUCTION: 0.06960752606391907 LOSS_Generator: 5.663408279418945 LOSS_Discriminator: 0.06960752606391907
# ITERATION_NO.: 65 LOSS_RECONSTRUCTION: 0.0054816692136228085 LOSS_Generator: 5.710456371307373 LOSS_Discriminator: 0.0054816692136228085
# ITERATION_NO.: 66 LOSS_RECONSTRUCTION: 0.053533878177404404 LOSS_Generator: 5.631668567657471 LOSS_Discriminator: 0.053533878177404404
# ITERATION_NO.: 67 LOSS_RECONSTRUCTION: 0.05745987221598625 LOSS_Generator: 5.594584941864014 LOSS_Discriminator: 0.05745987221598625
# ITERATION_NO.: 68 LOSS_RECONSTRUCTION: 0.010349033400416374 LOSS_Generator: 5.554934978485107 LOSS_Discriminator: 0.010349033400416374
# ITERATION_NO.: 69 LOSS_RECONSTRUCTION: 0.006589987315237522 LOSS_Generator: 5.729964256286621 LOSS_Discriminator: 0.006589987315237522
# ITERATION_NO.: 70 LOSS_RECONSTRUCTION: 0.004349574446678162 LOSS_Generator: 5.631811618804932 LOSS_Discriminator: 0.004349574446678162
# ITERATION_NO.: 71 LOSS_RECONSTRUCTION: 0.028497161343693733 LOSS_Generator: 5.916609764099121 LOSS_Discriminator: 0.028497161343693733
# ITERATION_NO.: 72 LOSS_RECONSTRUCTION: 0.004138035234063864 LOSS_Generator: 5.940401554107666 LOSS_Discriminator: 0.004138035234063864
# ITERATION_NO.: 73 LOSS_RECONSTRUCTION: 0.004773206543177366 LOSS_Generator: 5.877768039703369 LOSS_Discriminator: 0.004773206543177366
# ITERATION_NO.: 74 LOSS_RECONSTRUCTION: 0.0037538742180913687 LOSS_Generator: 5.998990535736084 LOSS_Discriminator: 0.0037538742180913687
# ITERATION_NO.: 75 LOSS_RECONSTRUCTION: 0.07216684520244598 LOSS_Generator: 5.930963039398193 LOSS_Discriminator: 0.07216684520244598
# ITERATION_NO.: 76 LOSS_RECONSTRUCTION: 0.004117568489164114 LOSS_Generator: 5.899588584899902 LOSS_Discriminator: 0.004117568489164114
# ITERATION_NO.: 77 LOSS_RECONSTRUCTION: 0.07047709077596664 LOSS_Generator: 5.971848487854004 LOSS_Discriminator: 0.07047709077596664
# ITERATION_NO.: 78 LOSS_RECONSTRUCTION: 0.004249289631843567 LOSS_Generator: 6.13892126083374 LOSS_Discriminator: 0.004249289631843567
# ITERATION_NO.: 79 LOSS_RECONSTRUCTION: 0.011835121549665928 LOSS_Generator: 6.166792869567871 LOSS_Discriminator: 0.011835121549665928
# ITERATION_NO.: 80 LOSS_RECONSTRUCTION: 0.002699072239920497 LOSS_Generator: 6.070607662200928 LOSS_Discriminator: 0.002699072239920497
# ITERATION_NO.: 81 LOSS_RECONSTRUCTION: 0.019968101754784584 LOSS_Generator: 6.192551612854004 LOSS_Discriminator: 0.019968101754784584
# ITERATION_NO.: 139 LOSS_RECONSTRUCTION: 0.014851405285298824 LOSS_Generator: 6.529372215270996 LOSS_Discriminator: 0.014851405285298824
# ITERATION_NO.: 140 LOSS_RECONSTRUCTION: 0.002355576492846012 LOSS_Generator: 6.552470684051514 LOSS_Discriminator: 0.002355576492846012
# ITERATION_NO.: 141 LOSS_RECONSTRUCTION: 0.03671489655971527 LOSS_Generator: 6.332556247711182 LOSS_Discriminator: 0.03671489655971527
# ITERATION_NO.: 142 LOSS_RECONSTRUCTION: 0.0025322309229522943 LOSS_Generator: 6.381230354309082 LOSS_Discriminator: 0.0025322309229522943
# ITERATION_NO.: 143 LOSS_RECONSTRUCTION: 0.06599684804677963 LOSS_Generator: 6.240089416503906 LOSS_Discriminator: 0.06599684804677963
# ITERATION_NO.: 144 LOSS_RECONSTRUCTION: 0.067157082259655 LOSS_Generator: 6.400371074676514 LOSS_Discriminator: 0.067157082259655
# ITERATION_NO.: 145 LOSS_RECONSTRUCTION: 0.05906685069203377 LOSS_Generator: 6.298532485961914 LOSS_Discriminator: 0.05906685069203377
# ITERATION_NO.: 146 LOSS_RECONSTRUCTION: 0.008561399765312672 LOSS_Generator: 5.998956203460693 LOSS_Discriminator: 0.008561399765312672
# ITERATION_NO.: 147 LOSS_RECONSTRUCTION: 0.0054830205626785755 LOSS_Generator: 5.99856424331665 LOSS_Discriminator: 0.0054830205626785755
# ITERATION_NO.: 148 LOSS_RECONSTRUCTION: 0.002882783068343997 LOSS_Generator: 6.150008201599121 LOSS_Discriminator: 0.002882783068343997
# ITERATION_NO.: 149 LOSS_RECONSTRUCTION: 0.006402119994163513 LOSS_Generator: 5.986713886260986 LOSS_Discriminator: 0.006402119994163513
# ITERATION_NO.: 150 LOSS_RECONSTRUCTION: 0.037636760622262955 LOSS_Generator: 6.010204792022705 LOSS_Discriminator: 0.037636760622262955
# ITERATION_NO.: 151 LOSS_RECONSTRUCTION: 0.005628214217722416 LOSS_Generator: 5.857043743133545 LOSS_Discriminator: 0.005628214217722416
# ITERATION_NO.: 152 LOSS_RECONSTRUCTION: 0.005297054536640644 LOSS_Generator: 5.674563884735107 LOSS_Discriminator: 0.005297054536640644
# ITERATION_NO.: 153 LOSS_RECONSTRUCTION: 0.028506526723504066 LOSS_Generator: 6.008951187133789 LOSS_Discriminator: 0.028506526723504066
# ITERATION_NO.: 154 LOSS_RECONSTRUCTION: 0.004840879235416651 LOSS_Generator: 6.079466342926025 LOSS_Discriminator: 0.004840879235416651
# ITERATION_NO.: 155 LOSS_RECONSTRUCTION: 0.005231157410889864 LOSS_Generator: 5.948019981384277 LOSS_Discriminator: 0.005231157410889864
# ITERATION_NO.: 156 LOSS_RECONSTRUCTION: 0.006295772269368172 LOSS_Generator: 5.855660915374756 LOSS_Discriminator: 0.006295772269368172
# ITERATION_NO.: 157 LOSS_RECONSTRUCTION: 0.05041676014661789 LOSS_Generator: 6.120799541473389 LOSS_Discriminator: 0.05041676014661789
# ITERATION_NO.: 575 LOSS_RECONSTRUCTION: 0.005182949360460043 LOSS_Generator: 6.2410502433776855 LOSS_Discriminator: 0.005182949360460043
# ITERATION_NO.: 576 LOSS_RECONSTRUCTION: 0.07169164717197418 LOSS_Generator: 6.348537445068359 LOSS_Discriminator: 0.07169164717197418
# ITERATION_NO.: 577 LOSS_RECONSTRUCTION: 0.1275264471769333 LOSS_Generator: 6.124407768249512 LOSS_Discriminator: 0.1275264471769333
# ITERATION_NO.: 578 LOSS_RECONSTRUCTION: 0.033707357943058014 LOSS_Generator: 5.998451232910156 LOSS_Discriminator: 0.033707357943058014
# ITERATION_NO.: 579 LOSS_RECONSTRUCTION: 0.002692269394174218 LOSS_Generator: 6.33335542678833 LOSS_Discriminator: 0.002692269394174218
# ITERATION_NO.: 580 LOSS_RECONSTRUCTION: 0.0030895445961505175 LOSS_Generator: 6.19132661819458 LOSS_Discriminator: 0.0030895445961505175
# ITERATION_NO.: 581 LOSS_RECONSTRUCTION: 0.0028892075642943382 LOSS_Generator: 6.143816947937012 LOSS_Discriminator: 0.0028892075642943382
# ITERATION_NO.: 582 LOSS_RECONSTRUCTION: 0.005148358177393675 LOSS_Generator: 6.275534629821777 LOSS_Discriminator: 0.005148358177393675
# ITERATION_NO.: 583 LOSS_RECONSTRUCTION: 0.0036383457481861115 LOSS_Generator: 6.441874980926514 LOSS_Discriminator: 0.0036383457481861115
# ITERATION_NO.: 584 LOSS_RECONSTRUCTION: 0.0032505670096725225 LOSS_Generator: 6.47227144241333 LOSS_Discriminator: 0.0032505670096725225
# ITERATION_NO.: 585 LOSS_RECONSTRUCTION: 0.01909596472978592 LOSS_Generator: 6.322360038757324 LOSS_Discriminator: 0.01909596472978592
# ITERATION_NO.: 586 LOSS_RECONSTRUCTION: 0.003284536534920335 LOSS_Generator: 6.47004508972168 LOSS_Discriminator: 0.003284536534920335
# ITERATION_NO.: 587 LOSS_RECONSTRUCTION: 0.0025025808718055487 LOSS_Generator: 6.491024017333984 LOSS_Discriminator: 0.0025025808718055487
# ITERATION_NO.: 588 LOSS_RECONSTRUCTION: 0.002043579239398241 LOSS_Generator: 6.568010330200195 LOSS_Discriminator: 0.002043579239398241
# ITERATION_NO.: 589 LOSS_RECONSTRUCTION: 0.10274921357631683 LOSS_Generator: 6.443897724151611 LOSS_Discriminator: 0.10274921357631683
# ITERATION_NO.: 590 LOSS_RECONSTRUCTION: 0.0027715133037418127 LOSS_Generator: 6.578392028808594 LOSS_Discriminator: 0.0027715133037418127
# ITERATION_NO.: 591 LOSS_RECONSTRUCTION: 0.0020140439737588167 LOSS_Generator: 6.673030853271484 LOSS_Discriminator: 0.0020140439737588167
# ITERATION_NO.: 592 LOSS_RECONSTRUCTION: 0.09294067323207855 LOSS_Generator: 6.452936172485352 LOSS_Discriminator: 0.09294067323207855
# ITERATION_NO.: 593 LOSS_RECONSTRUCTION: 0.05770908668637276 LOSS_Generator: 6.406774044036865 LOSS_Discriminator: 0.05770908668637276
# ITERATION_NO.: 594 LOSS_RECONSTRUCTION: 0.003052975283935666 LOSS_Generator: 6.323728561401367 LOSS_Discriminator: 0.003052975283935666
# ITERATION_NO.: 595 LOSS_RECONSTRUCTION: 0.004538035020232201 LOSS_Generator: 6.158632278442383 LOSS_Discriminator: 0.004538035020232201
# ITERATION_NO.: 596 LOSS_RECONSTRUCTION: 0.0023184942547231913 LOSS_Generator: 6.378705978393555 LOSS_Discriminator: 0.0023184942547231913
# ITERATION_NO.: 597 LOSS_RECONSTRUCTION: 0.0034057823941111565 LOSS_Generator: 6.441534042358398 LOSS_Discriminator: 0.0034057823941111565
# ITERATION_NO.: 598 LOSS_RECONSTRUCTION: 0.014916646294295788 LOSS_Generator: 6.37553596496582 LOSS_Discriminator: 0.014916646294295788
# ITERATION_NO.: 599 LOSS_RECONSTRUCTION: 0.03497825935482979 LOSS_Generator: 6.2526774406433105 LOSS_Discriminator: 0.03497825935482979
# ITERATION_NO.: 600 LOSS_RECONSTRUCTION: 0.06553677469491959 LOSS_Generator: 6.015348434448242 LOSS_Discriminator: 0.06553677469491959
# EPOCH OVER: 39
# 1
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Image_no 1
# Image_no 2
# Image_no 3
# Image_no 4
# Image_no 5
# Image_no 6
# Image_no 7
# Image_no 8
# Image_no 9
# Image_no 10
# Image_no 11
# Image_no 12
# Image_no 13
# Image_no 14
# Image_no 15
# Image_no 16
# Image_no 17
# Image_no 18
# Image_no 19
# Image_no 20
# Image_no 21
# Image_no 22
# Image_no 23
# Image_no 24
# Image_no 25
# Image_no 26
# Image_no 27
# Image_no 28
# Image_no 29
# Image_no 30
# Image_no 31
# Image_no 32
# Image_no 33
# Image_no 34
# Image_no 35
# Image_no 36
# Image_no 37
# Image_no 38
# Image_no 39
# Image_no 40
# Image_no 41
# Image_no 42
# Image_no 43
# Image_no 44
# Image_no 45
# Image_no 46
# Image_no 47
# Image_no 48
# Image_no 49
# Image_no 50
# Image_no 51
# Image_no 52
# Image_no 53
# Image_no 54
# Image_no 55
# Image_no 56
# Image_no 57
# Image_no 58
# Image_no 59
# Image_no 60
# Image_no 61
# Image_no 62
# Image_no 63
# Image_no 64
# Image_no 65
# Image_no 66
# Image_no 67
# Image_no 68
# Image_no 69
# Image_no 70
# Image_no 71
# Image_no 72
# Image_no 73
# Image_no 74
# Image_no 75
# Image_no 76
# Image_no 77
# Image_no 78
# Image_no 79
# Image_no 80
# Image_no 81
# Image_no 82
# Image_no 83
# Image_no 84
# Image_no 85
# Image_no 86
# Image_no 87
# Image_no 88
# Image_no 89
# Image_no 90
# Image_no 91
# Image_no 92
# Image_no 93
# Image_no 94
# Image_no 95
# Image_no 96
# Image_no 97
# Image_no 98
# Image_no 99
# Image_no 100
# Image_no 101
# Image_no 102
# Image_no 103
# Image_no 104
# Image_no 105
# Image_no 106
# Image_no 107
# Image_no 108
# Image_no 109
# Image_no 110
# Image_no 111
# Image_no 112
# Image_no 113
# Image_no 114
# Image_no 115
# Image_no 116
# Image_no 117
# Image_no 118
# Image_no 119
# Image_no 120
# Image_no 121
# Image_no 122
# Image_no 123
# Image_no 504
# Image_no 505
# Image_no 506
# Image_no 507
# Image_no 508
# Image_no 509
# Image_no 510
# Image_no 511
# Image_no 512
# Image_no 513
# Image_no 514
# Image_no 515
# Image_no 516
# Image_no 517
# Image_no 518
# Image_no 519
# Image_no 520
# Image_no 521
# Image_no 522
# Image_no 523
# Image_no 524
# Image_no 525
# Image_no 526
# Image_no 527
# Image_no 528
# Image_no 529
# Image_no 530
# Image_no 531
# Image_no 532
# Image_no 533
# Image_no 534
# Image_no 535
# Image_no 536
# Image_no 537
# Image_no 538
# Image_no 539
# Image_no 540
# Image_no 541
# Image_no 542
# Image_no 543
# Image_no 544
# Image_no 545
# Image_no 546
# Image_no 547
# Image_no 548
# Image_no 549
# Image_no 550
# Image_no 551
# Image_no 552
# Image_no 553
# Image_no 554
# Image_no 555
# Image_no 556
# Image_no 557
# Image_no 558
# Image_no 559
# Image_no 560
# Image_no 561
# Image_no 562
# Image_no 563
# Image_no 564
# Image_no 565
# Image_no 566
# Image_no 567
# Image_no 568
# Image_no 569
# Image_no 570
# Image_no 571
# Image_no 572
# Image_no 573
# Image_no 574
# Image_no 575
# Image_no 576
# Image_no 577
# Image_no 578
# Image_no 579
# Image_no 580
# Image_no 581
# Image_no 582
# Image_no 583
# Image_no 584
# Image_no 585
# Image_no 586
# Image_no 587
# Image_no 588
# Image_no 589
# Image_no 590
# Image_no 591
# Image_no 592
# Image_no 593
# Image_no 594
# Image_no 595
# Image_no 596
# Image_no 597
# Image_no 598
# Image_no 599
# Image_no 600

# %%
img=cv2.imread('testing200.png')
plt.imshow(img)

# %% [markdown]
# WE CAN SEE THE MIXING OCCURNG IN THE LATENT SPACE AND ESPECIALLY BECAUSE OF LOW DIMENSIONALITY 522 THOUGH THE POINTS IN LATENT SPACE ARE DISCRETE AND KIND OF ONE TO ONE MAPPING BUT THEY STILL SEEM TO BE QUITE CONTINUOUS. TAKING A HIGHER DIMENSIONAL DATASET MAY SHOW THE SPARSITY IN THE LATENT IN A BETTER WAY.

# %%
#layer3 visualization
fig=plt.figure(figsize=(8, 8))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img=cv2.imread('latent_layer1_'+str(i)+'.png')
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
#layer2 visualization
fig=plt.figure(figsize=(8, 8))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img=cv2.imread('latent_layer2_'+str(i)+'.png')
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
#layer1 visualization
fig=plt.figure(figsize=(8, 8))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img=cv2.imread('latent_layer1_'+str(i)+'.png')
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %% [markdown]
# SO IT SEEMS THAT THE LATENT SPACE IS VERY CONTINUOUS BUT IN REALITY IT IS DISCRETE IN CASE OF A NORMAL AUTOENCODER TO VISUALIZE IT WE NEED A LARGER DIMENSION DATASET TO PROOVE IT WE NEED TO PLOT THE LATENT SPACE BY CONVERTING IT INTO TWO DIMENSIONS USING PCA

# %%
#here is all it begins and ends
obj=training(plot=True)

# %%
print(a)
